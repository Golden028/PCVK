# %% [markdown]
# <a href="https://colab.research.google.com/github/Golden028/PCVK/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # D. PRACTICUM

# %% [markdown]
# # No.1

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg')
plt.imshow(img)                           #perhatikan hasilnya adalah citra dgn channel

# %% [markdown]
# # No.2

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)     #konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# # No.3

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK/Images/mandriii2.tiff', img5)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))       #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
plt.imshow(img5)

# %% [markdown]
# # No.4

# %%
black_img = np.zeros(shape=[512,512,3], dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(511,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))  #nilai 2 untuk menunjukan bahwa tiap titik dibuat 3 chanel yg mewakili
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # No.5

# %% [markdown]
# After all the code is finished save “Week2.ipynb” on your GiHub by selecting File then
# “Save a copy in GitHub”.

# %% [markdown]
# # **E. TASK**

# %% [markdown]
# Based on practicum parts 1 and 2, do the following tasks:

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x281>

# %% [markdown]
# 1. By using figsize, notice whether the image pixel size also changes?

# %%
img6 = img.copy()

fig = plt.figure(figsize=(4,8))
ax = fig.add_subplot(111)
ax.imshow(img6)

# %% [markdown]
# 2. Show images in Red-Green and Green-Blue channels only!

# %%
rg_image = np.copy(img)
gb_image = np.copy(img)

rg_image[:, :, 2] = 0
gb_image[:, :, 0] = 0

fig, axes = plt.subplots(1, 2, figsize=(12, 6))
axes[0].imshow(rg_image)
axes[0].set_title("Red-Green Channel Image")

axes[1].imshow(gb_image)
axes[1].set_title("Green-Blue Channel Image")
plt.show()
print("-" * 30)
# Out:
# ------------------------------

# %% [markdown]
# 3. Show image row 10-100, column 10-100!

# %%
cropped_image = img[10:101, 10:101, :]

plt.figure(figsize=(5, 5))
plt.imshow(cropped_image)
plt.show()

# %% [markdown]
# 4. Show image rows 5-30, all columns, channel Green only!

# %%
greenonlyimg = img6.copy()
greenonlyimg[:, :, 0] = 0
greenonlyimg[:, :, 2] = 0

cropgreen = greenonlyimg[5:31, :]

plt.figure(figsize=(12,5))
plt.imshow(cropgreen)
plt.show()

# %% [markdown]
# 5. Create 5 boxes of different sizes and colors in one image. it is recommended to use
# random numbers!

# %%
black_img3=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img3)

cv.rectangle(black_img3, pt1=(10,10), pt2=(100,100), color=(0,0,255), thickness=5)
plt.imshow(black_img3)

cv.circle(black_img3, center=(100,400), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img3)

cv.line(black_img3, pt1=(0,256), pt2=(511,256), color=(255,255,255), thickness=10)
plt.imshow(black_img3)

cv.ellipse(black_img3, center=(100,256), axes=(100,50), angle=0, startAngle=0, endAngle=360, color=(255,0,0), thickness=5)
plt.imshow(black_img3)

# %% [markdown]
# 6. Show the image upside down!

# %%
upside_down_image = black_img3[::-1, :, :]

plt.figure(figsize=(6, 6))
plt.imshow(upside_down_image)
plt.title("Image Flipped Upside Down")
plt.show()

# %% [markdown]
# 7. Make rectangles and circles on the face of your photo image when you are active
# (not a passport photo).

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/Images/Self.jpg')

face_img = img.copy()

cv.rectangle(face_img, (200, 150), (1000, 800), (0, 0, 255), 3)

cv.circle(face_img, (500, 460), 60, (0, 255, 0), 3)
cv.circle(face_img, (700, 460), 60, (0, 255, 0), 3)

face_img_rgb = cv.cvtColor(face_img, cv.COLOR_BGR2RGB)

plt.imshow(face_img_rgb)
plt.axis("off")
plt.show()

# %% [markdown]
# 8. Create a rectangle in the lower left corner of channel B in the RGB color space from
# the kitten / lena / mandrill / male / female / couple / sailboat / peppers image !

# %%
B_channel = img[:,:,0]   # channel B (dari BGR asli)
h, w = B_channel.shape
B_copy = cv.cvtColor(B_channel, cv.COLOR_GRAY2BGR)
cv.rectangle(B_copy, (0,h-300), (300,h), (255,0,0), 2)
plt.imshow(B_copy)
plt.show()

# %% [markdown]
# 9. Complete the writing of the file name on the image file from question no.8. use the
# font, font size, and font color according to your wishes.

# %%
B_text = B_copy.copy()
cv.putText(B_text, "Self.jpg", (10,h-350),
            cv.FONT_HERSHEY_SIMPLEX, 5, (0,255,255), 3)
plt.imshow(B_text)
plt.show()

# %% [markdown]
# 10. Show your program code to the lecturers

# %% [markdown]
# # **TASK GROUP 9 Golden and Yuma**

# %% [markdown]
# Group 9 closes the name of the province and district at the very top of the KTP.

# %%
img = cv.imread("/content/drive/MyDrive/PCVK/Images/KTP.jpg")

prov_coords_pt1 = (150, 30)
prov_coords_pt2 = (320, 50)
cv.rectangle(img, prov_coords_pt1, prov_coords_pt2,
             color=(0, 0, 0), thickness=-1)

dist_coords_pt1 = (180, 50)
dist_coords_pt2 = (300, 70)
cv.rectangle(img, dist_coords_pt1, dist_coords_pt2,
             color=(0, 0, 0), thickness=-1)

plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.axis("off")
plt.show()
